# %%
import pandas as pd
df = pd.read_csv('Raisin_Dataset.csv')
df
# Out:
#        area  major_axis_length  minor_axis_length  eccentricity  convex_area  \
# 0     87089         396.486857         280.245450      0.707392        88754
# 1     97377         503.992068         252.499625      0.865448       101317
# 2    126515         595.342557         277.909293      0.884360       134574
# 3     43495         271.646672         205.164069      0.655424        44535
# 4    118043         493.765244         308.000127      0.781601       122903
# ..      ...                ...                ...           ...          ...
# 895  105053         490.409597         277.084224      0.825087       107939
# 896   67468         424.563654         207.823052      0.872004        70674
# 897  142419         580.438197         318.180558      0.836365       145899
# 898  105091         507.685116         268.087343      0.849208       108296
# 899   89345         435.550880         262.061447      0.798739        91337
#
#        extent  perimeter    label
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df['label'], df['minor_axis_length'])
plt.title('Minor Axis Length of Both Raisin Types')
plt.xlabel('Label')
plt.ylabel('Minor Axis Length')
# Out:
# Text(0, 0.5, 'Minor Axis Length')

# %%
plt.bar(df['label'], df['major_axis_length'])
plt.title('Major Axis Length of Both Raisin Types')
plt.xlabel('Label')
plt.ylabel('Major Axis Length')
# Out:
# Text(0, 0.5, 'Major Axis Length')

# %%
plt.bar(df['label'], df['perimeter'])
plt.title('Perimeter of Both Raisin Types')
plt.xlabel('Label')
plt.ylabel('Perimeter')
# Out:
# Text(0, 0.5, 'Perimeter')

# %%
plt.scatter(df['area'], df['major_axis_length'])
plt.title('Relationship between Major Axis Length and Area')
plt.xlabel('Area')
plt.ylabel('Major Axis Length')
# Out:
# Text(0, 0.5, 'Major Axis Length')

# %%
plt.scatter(df['area'], df['minor_axis_length'])
plt.title('Relationship between Minor Axis Length and Area')
plt.xlabel('Area')
plt.ylabel('Minor Axis Length')
# Out:
# Text(0, 0.5, 'Minor Axis Length')

# %%
plt.scatter(df['eccentricity'], df['extent'])
plt.title('Relationship between Eccentricity and Extent')
plt.xlabel('Eccentricity')
plt.ylabel('Extent')
# Out:
# Text(0, 0.5, 'Extent')
